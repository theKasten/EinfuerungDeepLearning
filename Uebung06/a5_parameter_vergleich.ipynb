# %%
from denoising_autoencoder_mnist import autoencoder_mnist

my_autoencoder = autoencoder_mnist()
my_autoencoder.run()
# Out:
# Working on cpu.
# Epoch [1/5], Loss: 2.3448, Accuracy Test: 62.51%, Accuracy Train: 62.09%
# Epoch [2/5], Loss: 1.6887, Accuracy Test: 74.69%, Accuracy Train: 74.89%
# Epoch [3/5], Loss: 1.3691, Accuracy Test: 93.25%, Accuracy Train: 93.39%
# Epoch [4/5], Loss: 1.1661, Accuracy Test: 95.15%, Accuracy Train: 95.59%
# Epoch [5/5], Loss: 1.0089, Accuracy Test: 96.08%, Accuracy Train: 96.73%
